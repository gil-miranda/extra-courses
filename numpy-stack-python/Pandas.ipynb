# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Manual Data Loading

# %%
X = []
for line in open('datasets/data_2d.csv'):
    row = line.split(',')
    sample = list(map(float,row))
    X.append(sample)

# %%
X = np.array(X)

X.shape,X
# Out:
# ((100, 3), array([[1.79302012e+01, 9.45205920e+01, 3.20259530e+02],
#         [9.71446972e+01, 6.95932820e+01, 4.04634472e+02],
#         [8.17759008e+01, 5.73764810e+00, 1.81485108e+02],
#         [5.58543424e+01, 7.03259017e+01, 3.21773638e+02],
#         [4.93665500e+01, 7.51140402e+01, 3.22465486e+02],
#         [3.19270247e+00, 2.92562989e+01, 9.46188109e+01],
#         [4.92007841e+01, 8.61444385e+01, 3.56348093e+02],
#         [2.18828039e+01, 4.68415052e+01, 1.81653769e+02],
#         [7.95098627e+01, 8.73973555e+01, 4.23557743e+02],
#         [8.81538875e+01, 6.52056419e+01, 3.69229245e+02],
#         [6.07438543e+01, 9.99576339e+01, 4.27605804e+02],
#         [6.74155819e+01, 5.03683096e+01, 2.92471822e+02],
#         [4.83181158e+01, 9.91289531e+01, 3.95529811e+02],
#         [2.88299720e+01, 8.71849489e+01, 3.19031348e+02],
#         [4.38537427e+01, 6.44736391e+01, 2.87428144e+02],
#         [2.53136941e+01, 8.35452943e+01, 2.92768909e+02],
# ...

# %% [markdown]
# #### Loading Data using Pandas

# %%
X = pd.read_csv('datasets/data_2d.csv', header=None)

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
# 0    100 non-null float64
# 1    100 non-null float64
# 2    100 non-null float64
# dtypes: float64(3)
# memory usage: 2.4 KB

# %%
X.head()
# Out:
#            0          1           2
# 0  17.930201  94.520592  320.259530
# 1  97.144697  69.593282  404.634472
# 2  81.775901   5.737648  181.485108
# 3  55.854342  70.325902  321.773638
# 4  49.366550  75.114040  322.465486

# %%
X.head(10)
# Out:
#            0          1           2
# 0  17.930201  94.520592  320.259530
# 1  97.144697  69.593282  404.634472
# 2  81.775901   5.737648  181.485108
# 3  55.854342  70.325902  321.773638
# 4  49.366550  75.114040  322.465486
# 5   3.192702  29.256299   94.618811
# 6  49.200784  86.144439  356.348093
# 7  21.882804  46.841505  181.653769
# 8  79.509863  87.397356  423.557743
# 9  88.153887  65.205642  369.229245

# %%
M = X.values

# %%
M[:,0]
# Out:
# array([17.93020121, 97.14469719, 81.77590078, 55.85434242, 49.36654999,
#         3.19270247, 49.20078406, 21.8828039 , 79.50986272, 88.1538875 ,
#        60.74385434, 67.41558195, 48.31811577, 28.82997197, 43.85374266,
#        25.31369409, 10.80772667, 98.36574588, 29.14690997, 65.1003019 ,
#        24.64411349, 37.55980488, 88.16450624, 13.83462084, 64.41084375,
#        68.9259918 , 39.48844224, 52.46317768, 48.48478698,  8.06208781,
#        32.73188771, 11.6523788 , 13.73035353,  8.18555177, 53.60987615,
#        95.36860989, 87.33360921, 66.35761109, 19.75471753, 21.13344045,
#        22.37386481, 93.99040405, 86.7201981 , 98.99837299,  3.59396564,
#        15.10236337, 97.83414077, 19.93821969, 30.37351114, 73.29288315,
#        52.23090088, 86.42957611, 93.40080214, 13.21346006,  4.5934627 ,
#        15.66929158, 52.95935977, 56.81752123, 51.13354308,  7.86216472,
#        54.6986037 , 86.39906301, 11.94750602, 70.35840106, 29.02236633,
# ...

# %%
X[0]
# Desta forma selecionamos uma coluna quando o objeto é um Panda DataFrame
# Out:
# 0     17.930201
# 1     97.144697
# 2     81.775901
# 3     55.854342
# 4     49.366550
# 5      3.192702
# 6     49.200784
# 7     21.882804
# 8     79.509863
# 9     88.153887
# 10    60.743854
# 11    67.415582
# 12    48.318116
# 13    28.829972
# 14    43.853743
# 15    25.313694
# 16    10.807727
# 17    98.365746
# 18    29.146910
# 19    65.100302
# 20    24.644113
# 21    37.559805
# 22    88.164506
# 23    13.834621
# 24    64.410844
# 25    68.925992
# 26    39.488442
# 27    52.463178
# 28    48.484787
# 29     8.062088
#         ...
# 70    30.187692
# 71    11.788418
# 72    18.292424
# 73    96.712668
# 74    31.012739
# 75    11.397261
# 76    17.392556
# 77    72.182694
# 78    73.980021
# 79    94.493058
# 80    84.562821
# 81    51.742474
# 82    53.748590
# 83    85.050835
# 84    46.777250
# 85    49.758434
# 86    24.119257
# 87    27.201576
# 88     7.009596
# 89    97.646950
# 90     1.382983
# 91    22.323530
# 92    45.045406
# 93    40.163991
# ...

# %%
type(X[0])
# Out:
# pandas.core.series.Series

# %%
X.iloc[0] # Quando o objeto é um Panda DataFrame, podemos selecionar uma linha com iloc, passando o indice
# Out:
# 0     17.930201
# 1     94.520592
# 2    320.259530
# Name: 0, dtype: float64

# %%
X.loc[0] # Ou podemos selecionar uma linha com loc, passando o nome da coluna
# Out:
# 0     17.930201
# 1     94.520592
# 2    320.259530
# Name: 0, dtype: float64

# %%
type(X.iloc[0]),type(X.loc[0])
# Out:
# (pandas.core.series.Series, pandas.core.series.Series)

# %%
## Selecionar multiplas colunas
X[[0,2]]
# Out:
#             0           2
# 0   17.930201  320.259530
# 1   97.144697  404.634472
# 2   81.775901  181.485108
# 3   55.854342  321.773638
# 4   49.366550  322.465486
# 5    3.192702   94.618811
# 6   49.200784  356.348093
# 7   21.882804  181.653769
# 8   79.509863  423.557743
# 9   88.153887  369.229245
# 10  60.743854  427.605804
# 11  67.415582  292.471822
# 12  48.318116  395.529811
# 13  28.829972  319.031348
# 14  43.853743  287.428144
# 15  25.313694  292.768909
# 16  10.807727  159.663308
# 17  98.365746  438.798964
# 18  29.146910  250.986309
# 19  65.100302  231.711508
# 20  24.644113  163.398161
# 21  37.559805   83.480155
# 22  88.164506  466.265806
# 23  13.834621  100.886430
# 24  64.410844  365.641048
# 25  68.925992  426.140015
# 26  39.488442  235.532389
# 27  52.463178  283.291640
# 28  48.484787  298.581440
# 29   8.062088  309.234109
# ..        ...         ...
# 70  30.187692   89.539008
# 71  11.788418  181.550683
# 72  18.292424  224.773383
# ...

# %%
## Seleção condicionada
X[X[0] < 5]
# Out:
#            0          1           2
# 5   3.192702  29.256299   94.618811
# 44  3.593966  96.252217  293.237183
# 54  4.593463  46.335932  145.818745
# 90  1.382983  84.944087  252.905653
# 99  4.142669  52.254726  168.034401

# %%
X[X[0]< 10]
# Out:
#            0          1           2
# 5   3.192702  29.256299   94.618811
# 29  8.062088  98.242600  309.234109
# 33  8.185552  41.851989  153.484189
# 44  3.593966  96.252217  293.237183
# 54  4.593463  46.335932  145.818745
# 59  7.862165  17.729082   69.355589
# 88  7.009596  55.876058  176.810149
# 90  1.382983  84.944087  252.905653
# 99  4.142669  52.254726  168.034401

# %%
X[0] < 10
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5      True
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29     True
#       ...
# 70    False
# 71    False
# 72    False
# 73    False
# 74    False
# 75    False
# 76    False
# 77    False
# 78    False
# 79    False
# 80    False
# 81    False
# 82    False
# 83    False
# 84    False
# 85    False
# 86    False
# 87    False
# 88     True
# 89    False
# 90     True
# 91    False
# 92    False
# 93    False
# 94    False
# 95    False
# 96    False
# 97    False
# 98    False
# 99     True
# Name: 0, Length: 100, dtype: bool

# %% [markdown]
# ### More DataFrames

# %%
df = pd.read_csv('datasets/international-airline-passengers.csv', engine='python', skipfooter=3)

# %%
df
# Out:
#        Month  \
# 0    1949-01
# 1    1949-02
# 2    1949-03
# 3    1949-04
# 4    1949-05
# 5    1949-06
# 6    1949-07
# 7    1949-08
# 8    1949-09
# 9    1949-10
# 10   1949-11
# 11   1949-12
# 12   1950-01
# 13   1950-02
# 14   1950-03
# 15   1950-04
# 16   1950-05
# 17   1950-06
# 18   1950-07
# 19   1950-08
# 20   1950-09
# 21   1950-10
# 22   1950-11
# 23   1950-12
# 24   1951-01
# 25   1951-02
# 26   1951-03
# 27   1951-04
# 28   1951-05
# 29   1951-06
# ..       ...
# 114  1958-07
# 115  1958-08
# 116  1958-09
# 117  1958-10
# 118  1958-11
# 119  1958-12
# 120  1959-01
# 121  1959-02
# 122  1959-03
# 123  1959-04
# 124  1959-05
# 125  1959-06
# 126  1959-07
# 127  1959-08
# 128  1959-09
# 129  1959-10
# 130  1959-11
# 131  1959-12
# 132  1960-01
# 133  1960-02
# 134  1960-03
# 135  1960-04
# 136  1960-05
# 137  1960-06
# 138  1960-07
# 139  1960-08
# 140  1960-09
# 141  1960-10
# 142  1960-11
# 143  1960-12
#
# ...

# %%
df.columns
# Out:
# Index(['Month', 'International airline passengers: monthly totals in thousands. Jan 49 ? Dec 60'], dtype='object')

# %%
df.columns = ['month', 'passengers']

# %%
df.columns
# Out:
# Index(['month', 'passengers'], dtype='object')

# %%
df.head(10)
# Out:
#      month  passengers
# 0  1949-01         112
# 1  1949-02         118
# 2  1949-03         132
# 3  1949-04         129
# 4  1949-05         121
# 5  1949-06         135
# 6  1949-07         148
# 7  1949-08         148
# 8  1949-09         136
# 9  1949-10         119

# %%
df['passengers']
# Out:
# 0      112
# 1      118
# 2      132
# 3      129
# 4      121
# 5      135
# 6      148
# 7      148
# 8      136
# 9      119
# 10     104
# 11     118
# 12     115
# 13     126
# 14     141
# 15     135
# 16     125
# 17     149
# 18     170
# 19     170
# 20     158
# 21     133
# 22     114
# 23     140
# 24     145
# 25     150
# 26     178
# 27     163
# 28     172
# 29     178
#       ...
# 114    491
# 115    505
# 116    404
# 117    359
# 118    310
# 119    337
# 120    360
# 121    342
# 122    406
# 123    396
# 124    420
# 125    472
# 126    548
# 127    559
# 128    463
# 129    407
# 130    362
# 131    405
# 132    417
# 133    391
# 134    419
# 135    461
# 136    472
# 137    535
# 138    622
# 139    606
# 140    508
# 141    461
# 142    390
# 143    432
# Name: passengers, Length: 144, dtype: int64

# %%
df.passengers
# Out:
# 0      112
# 1      118
# 2      132
# 3      129
# 4      121
# 5      135
# 6      148
# 7      148
# 8      136
# 9      119
# 10     104
# 11     118
# 12     115
# 13     126
# 14     141
# 15     135
# 16     125
# 17     149
# 18     170
# 19     170
# 20     158
# 21     133
# 22     114
# 23     140
# 24     145
# 25     150
# 26     178
# 27     163
# 28     172
# 29     178
#       ...
# 114    491
# 115    505
# 116    404
# 117    359
# 118    310
# 119    337
# 120    360
# 121    342
# 122    406
# 123    396
# 124    420
# 125    472
# 126    548
# 127    559
# 128    463
# 129    407
# 130    362
# 131    405
# 132    417
# 133    391
# 134    419
# 135    461
# 136    472
# 137    535
# 138    622
# 139    606
# 140    508
# 141    461
# 142    390
# 143    432
# Name: passengers, Length: 144, dtype: int64

# %%
df['ones'] = 1 # Cria nova coluna e preenche com 1

# %%
df.head()
# Out:
#      month  passengers  ones
# 0  1949-01         112     1
# 1  1949-02         118     1
# 2  1949-03         132     1
# 3  1949-04         129     1
# 4  1949-05         121     1

# %%
from datetime import datetime

# %%
## Adicionando novas colunas e aplicando funções a elas

# %%
datetime.strptime("1949-05","%Y-%m")
# Out:
# datetime.datetime(1949, 5, 1, 0, 0)

# %%
df['dt'] = df.apply(lambda row: datetime.strptime(row['month'], '%Y-%m'), axis=1)

# %%
df.head()
# Out:
#      month  passengers  ones         dt
# 0  1949-01         112     1 1949-01-01
# 1  1949-02         118     1 1949-02-01
# 2  1949-03         132     1 1949-03-01
# 3  1949-04         129     1 1949-04-01
# 4  1949-05         121     1 1949-05-01

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 4 columns):
# month         144 non-null object
# passengers    144 non-null int64
# ones          144 non-null int64
# dt            144 non-null datetime64[ns]
# dtypes: datetime64[ns](1), int64(2), object(1)
# memory usage: 4.6+ KB

# %% [markdown]
# ### Joins

# %%
t1 = pd.read_csv('datasets/table1.csv')
t2 = pd.read_csv('datasets/table2.csv')

# %%
t1
# Out:
#    user_id            email  age
# 0        1  alice@gmail.com   20
# 1        2    bob@gmail.com   25
# 2        3  carol@gmail.com   30

# %%
t2
# Out:
#     user_id  ad_id  click
# 0         1      1      1
# 1         1      2      0
# 2         1      5      0
# 3         2      3      0
# 4         2      4      1
# 5         2      1      0
# 6         3      2      0
# 7         3      1      0
# 8         3      3      0
# 9         3      4      0
# 10        3      5      1

# %%
m = pd.merge(t1,t2, on='user_id')
m
# Out:
#     user_id            email  age  ad_id  click
# 0         1  alice@gmail.com   20      1      1
# 1         1  alice@gmail.com   20      2      0
# 2         1  alice@gmail.com   20      5      0
# 3         2    bob@gmail.com   25      3      0
# 4         2    bob@gmail.com   25      4      1
# 5         2    bob@gmail.com   25      1      0
# 6         3  carol@gmail.com   30      2      0
# 7         3  carol@gmail.com   30      1      0
# 8         3  carol@gmail.com   30      3      0
# 9         3  carol@gmail.com   30      4      0
# 10        3  carol@gmail.com   30      5      1
