# %%
from scipy.stats import norm
import numpy as np
import matplotlib.pyplot as plt

# %%
norm.pdf(0)
# Out:
# 0.3989422804014327

# %%
r = np.random.random(10)
r
# Out:
# array([0.29598072, 0.57177607, 0.59227621, 0.07265658, 0.08451382,
#        0.50358424, 0.5628089 , 0.92308878, 0.4828126 , 0.4855208 ])

# %%
a = norm.pdf(r)
a
# Out:
# array([0.38184488, 0.33878064, 0.33476245, 0.39789066, 0.39752008,
#        0.35143269, 0.34050841, 0.26054362, 0.35505146, 0.35458622])

# %%
plt.hist(a)
# Out:
# (array([1., 0., 0., 0., 0., 3., 3., 0., 1., 2.]),
#  array([0.26054362, 0.27427832, 0.28801303, 0.30174773, 0.31548244,
#         0.32921714, 0.34295185, 0.35668655, 0.37042126, 0.38415596,
#         0.39789066]),
#  <a list of 10 Patch objects>)

# %%
b = norm.logpdf(r)
b
# Out:
# array([-0.96274083, -1.08240247, -1.09433409, -0.92157802, -0.92250983,
#        -1.04573707, -1.07731546, -1.34498498, -1.03549254, -1.03680376])

# %%
plt.hist(b)
# Out:
# (array([1., 0., 0., 0., 0., 1., 2., 3., 0., 3.]),
#  array([-1.34498498, -1.30264429, -1.26030359, -1.2179629 , -1.1756222 ,
#         -1.1332815 , -1.09094081, -1.04860011, -1.00625942, -0.96391872,
#         -0.92157802]),
#  <a list of 10 Patch objects>)

# %%
norm.cdf(r)
# Out:
# array([0.6163776 , 0.71626316, 0.72316718, 0.5289603 , 0.53367604,
#        0.69272321, 0.71321749, 0.82201953, 0.6853856 , 0.68634652])

# %%
norm.logcdf(r)
# Out:
# array([-0.48389552, -0.33370764, -0.32411485, -0.6368419 , -0.62796628,
#        -0.36712476, -0.33796887, -0.19599112, -0.37777368, -0.37637265])

# %%
g = np.random.randn(10000)

# %%
plt.hist(g, bins=100)
plt.show()

# %%
r = 10*np.random.randn(10000)+5

# %%
plt.hist(r,bins=100)
plt.show()

# %%
r = np.random.randn(10000,2)

# %%
plt.scatter(r[:,0],r[:,1])
plt.show()

# %%
s
